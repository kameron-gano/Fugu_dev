# %%
import os
import networkx as nx
import numpy as np
import pandas as pd
import random

from fugu.scaffold.scaffold import Scaffold
from fugu.bricks.bricks import Brick
from fugu.backends.snn_backend import snn_Backend

# Get the absolute path of the current script
os.getcwd()
# Out:
# '/Users/kamerongano/Documents/GitHub/Fugu_dev/fugu/nscale'

# %%
# network settings
# 200 neurons, 20% connectivity, 1 weight, bias of 1, threshold of 100, run for 500 time steps
SANA_FE = True
num_neurons = 200
bias = 1
th = 100
prob_w = 0.2
w = 1
time = 500

# %%
# connectivity matrix
seed = 42
random.seed(seed)
np.random.seed(seed)

connec_matrix = []
for i in range(num_neurons):
    connec_vector = []
    for j in range(num_neurons):
        if random.random() < prob_w:
            connec_vector.append(1)
        else:
            connec_vector.append(0)
    connec_matrix.append(connec_vector)
#connec_matrix

# %%
# making a brick based off of the above settings
class recurrent(Brick):
    def __init__(self, name=None):
        super().__init__()
        self.is_built = False
        self.metadata = {'D':1}  
        self.name = name
    def build(self,
             graph,
             metadata,
             control_nodes,
             input_lists,
             input_codings):

        output_codings = []

        #We also, obviously, need to build the computational portion of our graph
        for i in range(num_neurons):
            graph.add_node(self.name + '_' + str(i),
                           index=i,
                           threshold=th,
                           decay=0.0,
                           bias=bias,
                           p=1.0,
                           potential=0.0
                          )
        for i in range(num_neurons):
            for j in range(num_neurons):
                if connec_matrix[i][j] == 1:
                    graph.add_edge(self.name + '_' + str(i),
                                  self.name + '_' + str(j),
                                  weight=w,
                                  delay=1.0)
        self.is_built=True
        
        # bricks can have more than one output
        output_lists = []
        
        return (graph,
               self.metadata,
                [],
                output_lists,
                output_codings
               )

# %%
scaffold = Scaffold()
scaffold.add_brick(recurrent(name='recurrent'), [], output=True)
scaffold.lay_bricks()
#scaffold.summary(verbose=2)

# %%
if SANA_FE:
    # get sanafe backend and compile the scaffold
    # TODO: move arch YAML file to fugu
    from sanafe import fugu as sf
    ARCH_FILENAME = "/Users/kamerongano/Documents/Github/SANA-FE/arch/neuroscale.yaml"
    MAPPINGS = "core_mappings.json"

    #backend = snn_Backend()
    backend = sf.sanafe_Backend()
    backend_args = {}
    backend_args['record'] = 'all'
    backend_args['arch'] = ARCH_FILENAME
    backend_args['mappings'] = MAPPINGS
    #backend_args['debug_mode'] = True # show the optential at each time
    backend.compile(scaffold, backend_args)
else:
    # use regular snn backend
    backend = snn_Backend()
    backend_args = {}
    backend_args['record'] = 'all'
    #backend_args['debug_mode'] = True # show the optential at each time
    backend.compile(scaffold, backend_args)
# Out:
# fugu:{'index': 0, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 0}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_0
# fugu:{'index': 1, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 1}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_1
# fugu:{'index': 2, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 2}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_2
# fugu:{'index': 3, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 3}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_3
# fugu:{'index': 4, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 4}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_4
# fugu:{'index': 5, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 5}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_5
# fugu:{'index': 6, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 6}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_6
# fugu:{'index': 7, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 7}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_7
# fugu:{'index': 8, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 8}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_8
# fugu:{'index': 9, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 9}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_9
# fugu:{'index': 10, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 10}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_10
# fugu:{'index': 11, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 11}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_11
# fugu:{'index': 12, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 12}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_12
# fugu:{'index': 13, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 13}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_13
# fugu:{'index': 14, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 14}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_14
# fugu:{'index': 15, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 15}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_15
# fugu:{'index': 16, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 16}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_16
# fugu:{'index': 17, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number':
 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 179}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_179
# fugu:{'index': 180, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 180}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_180
# fugu:{'index': 181, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 181}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_181
# fugu:{'index': 182, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 182}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_182
# fugu:{'index': 183, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 183}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_183
# fugu:{'index': 184, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 184}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_184
# fugu:{'index': 185, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 185}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_185
# fugu:{'index': 186, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 186}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_186
# fugu:{'index': 187, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 187}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_187
# fugu:{'index': 188, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 188}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_188
# fugu:{'index': 189, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 189}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_189
# fugu:{'index': 190, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 190}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_190
# fugu:{'index': 191, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 191}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_191
# fugu:{'index': 192, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 192}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_192
# fugu:{'index': 193, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 193}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_193
# fugu:{'index': 194, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 194}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_194
# fugu:{'index': 195, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 195}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_195
# fugu:{'index': 196, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 196}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_196
# fugu:{'index': 197, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 197}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_197
# fugu:{'index': 198, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 198}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_198
# fugu:{'index': 199, 'threshold': 100, 'decay': 0.0, 'bias': 1, 'p': 1.0, 'potential': 0.0, 'brick': 'Brick-0', 'neuron_number': 199}
# sanafe_props:{'threshold': 100, 'leak_decay': 1.0, 'bias': 1, 'potential': 0.0}
# Enabling logging for neuron recurrent_199

# %%
result = backend.run(time)
# type(result) # pandas.core.frame.DataFrame
# Out:
# /Users/kamerongano/Documents/Github/SANA-FE/arch/neuroscale.yaml
# Warning: multiple threads not supported; flag ignored ( 0 )
# Executed steps: [500/500]

# %%
matrix = result.to_numpy()

# %%
spike_times = {}
for i in range(num_neurons):
    spike_times[i] = []
for i in matrix:
    spike_times[i[1]].append(int(i[0]))
#spike_times

# %%
# record the spikes into spikes_fugu.json file
import json
with open('spikes_fugu.json', 'w') as file:
    json.dump(spike_times, file)

# %%
def gen_json(graph, timestamps, path):
    # json file
    network_json = {}
    network_json['ticks'] = timestamps
    network_json['neuron_dict'] = {}
    network_json['synapse_dict'] = {}
    
    for i, neuron in enumerate(sorted(graph.nodes)):
        neuron_info = graph.nodes[neuron]
        network_json['neuron_dict'][str(neuron_info['neuron_number'])] = {"fan-in": [],
                                                                     "fan-out": [],
                                                                     "th": neuron_info['threshold'],
                                                                     "leak": 0.0,
                                                                     "bias": 0.0,
                                                                     "refractory period": 0,
                                                                     "prob": neuron_info['p']
                                                                    }
        if 'leakage_constant' in neuron_info:
            network_json['neuron_dict'][str(neuron_info['neuron_number'])]['leak'] = neuron_info['leakage_constant']
        if 'bias' in neuron_info:
            network_json['neuron_dict'][str(neuron_info['neuron_number'])]['bias'] = neuron_info['bias'] 
        if 'refractory_period' in neuron_info:
            network_json['neuron_dict'][str(neuron_info['neuron_number'])]['refractory_period'] = neuron_info['refractory_period']    
    
    for i, synapse in enumerate(graph.edges):
        pre_neuron = graph.nodes[synapse[0]]['neuron_number']
        post_neuron = graph.nodes[synapse[1]]['neuron_number']
        network_json['neuron_dict'][str(post_neuron)]['fan-in'].append(pre_neuron)
        network_json['neuron_dict'][str(pre_neuron)]['fan-out'].append(post_neuron)
        if str(post_neuron) not in network_json['synapse_dict']:
            network_json['synapse_dict'][str(post_neuron)] = {}
        if str(pre_neuron) not in network_json['synapse_dict'][str(post_neuron)]:
            network_json['synapse_dict'][str(post_neuron)][str(pre_neuron)] = {}
        network_json['synapse_dict'][str(post_neuron)][str(pre_neuron)][str(len(network_json['synapse_dict'][str(post_neuron)][str(pre_neuron)]))] = {'fixed-wt': graph.edges[synapse]['weight'],
                                                                                                                                                      'delay': graph.edges[synapse]['delay']}
    with open(path, 'w') as f:
        json.dump(network_json, f)

# %%
gen_json(scaffold.graph, time, "network.json")
