# %% [markdown]
# # LoihiGS Brick Tests
#
# This notebook runs the unit test for `LoihiGSBrick` which validates the preprocessing
# (fan-out enforcement) and mapping to Loihi-style synapses (forward/backward delays).

# %%
import pytest
import sys
# run the single test file
res = pytest.main(['-q', '../../tests/unit/bricks/test_loihi_gs_brick.py'])
print('pytest exit code ->', res)
# Out:
# .                                                                        [100%]
# 1 passed in 0.11s
# pytest exit code -> 0
